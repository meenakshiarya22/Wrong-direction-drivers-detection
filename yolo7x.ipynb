# %% [markdown]
# <a href="https://colab.research.google.com/github/meenakshiarya22/Wrong-direction-drivers-detection/blob/master/yolo7x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/yolov7

# %%
# !pip install -r requirements.txt

# %%
# !pip install -r requirements_gpu.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu113
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.6/1.6 GB 42.3 MB/s eta 0:00:01tcmalloc: large alloc 1636999168 bytes == 0x3314000 @  0x7f3cd795a680 0x7f3cd797b824 0x5b3128 0x5bbc90 0x5f714c 0x64d800 0x527022 0x504866 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x5f5ee6 0x56bbe1 0x569d8a 0x5f60c3 0x56cc92 0x569d8a 0x5f60c3
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.6/1.6 GB 42.3 MB/s eta 0:00:01tcmalloc: large alloc 2046255104 bytes == 0x64c3e000 @  0x7f3cd795a680 0x7f3cd797ada2 0x5f714c 0x64d800 0x527022 0x504866 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x569d8a 0x5f60c3 0x56bbe1 0x5f5ee6 0x56bbe1 0x569d8a 0x5f60c3 0x56cc92 0x569d8a 0x5f60c3 0x56bbe1 0x569d8a
# ...

# %%
# !python3 train.py --workers 1 --epochs 200 --device 0 --batch-size 8 --data data/coco.yaml --img 640 640 --cfg /content/drive/MyDrive/yolov7/cfg/training/yolov7x.yaml --weights 'yolov7x.pt' --name yolov7-x --hyp data/hyp.scratch.custom.yaml
# Out:
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15109.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='/content/drive/MyDrive/yolov7/cfg/training/yolov7x.yaml', data='data/coco.yaml', device='0', entity=None, epochs=200, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7-x', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7-x', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, v5_metric=False, weights='yolov7x.pt', workers=1, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python3 detect.py --weights runs/train/yolov7-x/weights/best.pt --img 640 --conf 0.5 --save-txt --save-conf --name 200_best --source /content/drive/MyDrive/yolov7/data/test/images
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='200_best', no_trace=False, nosave=False, project='runs/detect', save_conf=True, save_txt=True, source='/content/drive/MyDrive/yolov7/data/test/images', update=False, view_img=False, weights=['runs/train/yolov7-x/weights/best.pt'])
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15109.875MB)
#
# Fusing layers...
# IDetect.fuse
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 362 layers, 70789182 parameters, 0 gradients, 188.0 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...
